# %%
# !pip install yahoo-finance
# Out:
# ...
#     100% |████████████████████████████████| 81kB 1.5MB/s ta 0:00:011
# ...
#   Running setup.py bdist_wheel for yahoo-finance ... done
#   Stored in directory: /Users/linlyn/Library/Caches/pip/wheels/8b/32/7a/1b3e589e823ef2b8e510a99d11e3abae8f28af2ab8d4eaa884
#   Running setup.py bdist_wheel for simplejson ... done
#   Stored in directory: /Users/linlyn/Library/Caches/pip/wheels/c2/d0/42/5d1d1290c19d999277582c585f80426c61987aff01eb104ed6
# Successfully built yahoo-finance simplejson
# ...

# %%
#import packages
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
import re 
import pickle

#decide date range
style.use('ggplot')

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)
#turn into pandas dataframe
tsla = web.DataReader('TSLA', "yahoo", start, end)
print ("Tesla Inc. (TSLA)")
tsla['Name'] = "Tesla Inc. (TSLA)"
tsla.head()
# Out:
# Tesla Inc. (TSLA)
#                  Open   High        Low      Close  Adj Close    Volume  \
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900
#
#                          Name
# Date
# 2010-06-29  Tesla Inc. (TSLA)
# 2010-06-30  Tesla Inc. (TSLA)
# 2010-07-01  Tesla Inc. (TSLA)
# 2010-07-02  Tesla Inc. (TSLA)
# 2010-07-06  Tesla Inc. (TSLA)

# %%
tsla = tsla.rename(columns = {'Open': 'TSLA_Open' , 'High' : 'TSLA_High', 'Low': 'TSLA_Low', 'Close': 'TSLA_Close', 'Adj Close': 'TSLA_Adj Close', 'Volume': 'TSLA_Volume'})
tsla.head()
# Out:
#             TSLA_Open  TSLA_High   TSLA_Low  TSLA_Close  TSLA_Adj Close  \
# Date
# 2010-06-29  19.000000      25.00  17.540001   23.889999       23.889999
# 2010-06-30  25.790001      30.42  23.299999   23.830000       23.830000
# 2010-07-01  25.000000      25.92  20.270000   21.959999       21.959999
# 2010-07-02  23.000000      23.10  18.709999   19.200001       19.200001
# 2010-07-06  20.000000      20.00  15.830000   16.110001       16.110001
#
#             TSLA_Volume               Name
# Date
# 2010-06-29     18766300  Tesla Inc. (TSLA)
# 2010-06-30     17187100  Tesla Inc. (TSLA)
# 2010-07-01      8218800  Tesla Inc. (TSLA)
# 2010-07-02      5139800  Tesla Inc. (TSLA)
# 2010-07-06      6866900  Tesla Inc. (TSLA)

# %%
import pandas_datareader.data as web
import datetime

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)

tslaD = web.DataReader('TSLA', 'yahoo-dividends', start, end)
tslaD.head()
# Out:
# Empty DataFrame
# Columns: [Dividends]
# Index: []

# %%
# the timescale of plotted data
tsla.TSLA_Close.plot()
tsla.TSLA_Close.plot(plt.show())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-db02b11e9d04> in <module>()
#       1 # the timescale of plotted data
#       2 tsla.TSLA_Close.plot()
# ----> 3 tsla.TSLA_Close.plot(plt.show())
#
# /anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2451                            colormap=colormap, table=table, yerr=yerr,
#    2452                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2453                            **kwds)
#    2454     __call__.__doc__ = plot_series.__doc__
#    2455
#
# ...

# %%
#import packages
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web


#decide date range
style.use('ggplot')

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)
#turn into pandas dataframe
dps = web.DataReader('DPS', "yahoo", start, end)
print ('Dr Pepper Snapple Group Inc. (DPS)')
dps['Name'] = "Dr Pepper Snapple Group Inc. (DPS)"
dps.tail()
# Out:
# Dr Pepper Snapple Group Inc. (DPS)
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2017-12-11  94.029999  94.550003  93.000000  94.519997  93.937782   721600
# 2017-12-12  94.250000  95.070000  93.639999  94.160004  93.580002  1175800
# 2017-12-13  93.330002  94.010002  92.739998  93.760002  93.760002  1201200
# 2017-12-14  93.739998  94.000000  92.970001  92.980003  92.980003  1238100
# 2017-12-15  93.500000  93.989998  93.129997  93.919998  93.919998  1447223
#
#                                           Name
# Date
# 2017-12-11  Dr Pepper Snapple Group Inc. (DPS)
# 2017-12-12  Dr Pepper Snapple Group Inc. (DPS)
# 2017-12-13  Dr Pepper Snapple Group Inc. (DPS)
# 2017-12-14  Dr Pepper Snapple Group Inc. (DPS)
# 2017-12-15  Dr Pepper Snapple Group Inc. (DPS)

# %%
dps = dps.rename(columns = {'Open': 'DPS_Open' , 'High' : 'DPS_High', 'Low': 'DPS_Low', 'Close': 'DPS_Close', 'Adj Close': 'DPS_Adj Close', 'Volume': 'DPS_Volume'})
dps.head()
# Out:
#              DPS_Open   DPS_High    DPS_Low  DPS_Close  DPS_Adj Close  \
# Date
# 2008-05-07  25.200001  25.799999  24.799999      25.50      20.331610
# 2008-05-08  25.580000  25.830000  24.740000      25.40      20.251881
# 2008-05-09  25.100000  25.400000  24.940001      25.24      20.124311
# 2008-05-12  25.110001  26.850000  25.100000      25.57      20.387430
# 2008-05-13  25.379999  25.920000  25.200001      25.90      20.650539
#
#             DPS_Volume                                Name
# Date
# 2008-05-07    38943400  Dr Pepper Snapple Group Inc. (DPS)
# 2008-05-08    12468400  Dr Pepper Snapple Group Inc. (DPS)
# 2008-05-09     9747000  Dr Pepper Snapple Group Inc. (DPS)
# 2008-05-12     7921800  Dr Pepper Snapple Group Inc. (DPS)
# 2008-05-13     4518800  Dr Pepper Snapple Group Inc. (DPS)

# %%
import pandas_datareader.data as web
import datetime

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)

dpsD = web.DataReader('DPS', 'yahoo-dividends', start, end)
dpsD.head()
# Out:
#             Dividends
# Date
# 2009-12-17       0.15
# 2010-03-18       0.15
# 2010-06-17       0.25
# 2010-09-16       0.25
# 2010-12-16       0.25

# %%
# the timescale of plotted data
dps.DPS_Close.plot()
dps.DPS_Close.plot(plt.show())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-fc5082e8aa6e> in <module>()
#       1 # the timescale of plotted data
#       2 dps.DPS_Close.plot()
# ----> 3 dps.DPS_Close.plot(plt.show())
#
# /anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2451                            colormap=colormap, table=table, yerr=yerr,
#    2452                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2453                            **kwds)
#    2454     __call__.__doc__ = plot_series.__doc__
#    2455
#
# ...

# %%
#decide date range
style.use('ggplot')

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)
#turn into pandas dataframe
googl = web.DataReader('GOOGL', "yahoo", start, end)
print ("Google Inc. (GOOGL)")
googl['Name'] = "Google Inc. (GOOGL)"
googl.head()
# Out:
# Google Inc. (GOOGL)
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  50.050049  52.082081  48.028027  50.220219  50.220219  44659000
# 2004-08-20  50.555557  54.594593  50.300301  54.209209  54.209209  22834300
# 2004-08-23  55.430431  56.796795  54.579578  54.754753  54.754753  18256100
# 2004-08-24  55.675674  55.855854  51.836838  52.487488  52.487488  15247300
# 2004-08-25  52.532532  54.054054  51.991993  53.053055  53.053055   9188600
#
#                            Name
# Date
# 2004-08-19  Google Inc. (GOOGL)
# 2004-08-20  Google Inc. (GOOGL)
# 2004-08-23  Google Inc. (GOOGL)
# 2004-08-24  Google Inc. (GOOGL)
# 2004-08-25  Google Inc. (GOOGL)

# %%
googl = googl.rename(columns = {'Open': 'GOOGL_Open' , 'High' : 'GOOGL_High', 'Low': 'GOOGL_Low', 'Close': 'GOOGL_Close', 'Adj Close': 'GOOGL_Adj Close', 'Volume': 'GOOGL_Volume'})
googl.head()
# Out:
#             GOOGL_Open  GOOGL_High  GOOGL_Low  GOOGL_Close  GOOGL_Adj Close  \
# Date
# 2004-08-19   50.050049   52.082081  48.028027    50.220219        50.220219
# 2004-08-20   50.555557   54.594593  50.300301    54.209209        54.209209
# 2004-08-23   55.430431   56.796795  54.579578    54.754753        54.754753
# 2004-08-24   55.675674   55.855854  51.836838    52.487488        52.487488
# 2004-08-25   52.532532   54.054054  51.991993    53.053055        53.053055
#
#             GOOGL_Volume                 Name
# Date
# 2004-08-19      44659000  Google Inc. (GOOGL)
# 2004-08-20      22834300  Google Inc. (GOOGL)
# 2004-08-23      18256100  Google Inc. (GOOGL)
# 2004-08-24      15247300  Google Inc. (GOOGL)
# 2004-08-25       9188600  Google Inc. (GOOGL)

# %%
import pandas_datareader.data as web
import datetime

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)

googlD = web.DataReader('GOOGL', 'yahoo-dividends', start, end)
googlD.head()
# Out:
# Empty DataFrame
# Columns: [Dividends]
# Index: []

# %%
# the timescale of plotted data
googl.GOOGL_Close.plot()
googl.GOOGL_Close.plot(plt.show())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-eaf6bb3696f5> in <module>()
#       1 # the timescale of plotted data
#       2 googl.GOOGL_Close.plot()
# ----> 3 googl.GOOGL_Close.plot(plt.show())
#
# /anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2451                            colormap=colormap, table=table, yerr=yerr,
#    2452                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2453                            **kwds)
#    2454     __call__.__doc__ = plot_series.__doc__
#    2455
#
# ...

# %%
#decide date range
style.use('ggplot')

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)
#turn into pandas dataframe
f = web.DataReader('F', "yahoo", start, end)
print ("Ford Motor Company (F)")
f['Name'] = "Ford Motor Company (F)"
f.head()
# Out:
# Ford Motor Company (F)
#                Open     High      Low    Close  Adj Close    Volume  \
# Date
# 2001-01-02  23.8125  24.9375  23.7500  24.3125  15.494719   5226500
# 2001-01-03  24.5625  25.5000  23.8750  25.1250  16.012533  11157800
# 2001-01-04  28.0000  28.0000  25.4375  26.9375  17.167669  14896200
# 2001-01-05  27.0000  27.0000  25.8750  26.2500  16.729515   6710900
# 2001-01-08  25.4375  26.0000  24.9375  25.6250  16.331194   5900300
#
#                               Name
# Date
# 2001-01-02  Ford Motor Company (F)
# 2001-01-03  Ford Motor Company (F)
# 2001-01-04  Ford Motor Company (F)
# 2001-01-05  Ford Motor Company (F)
# 2001-01-08  Ford Motor Company (F)

# %%
f = f.rename(columns = {'Open': 'F_Open' , 'High' : 'F_High', 'Low': 'F_Low', 'Close': 'F_Close', 'Adj Close': 'F_Adj Close', 'Volume': 'F_Volume'})
f.head()
# Out:
#              F_Open   F_High    F_Low  F_Close  F_Adj Close  F_Volume  \
# Date
# 2001-01-02  23.8125  24.9375  23.7500  24.3125    15.494719   5226500
# 2001-01-03  24.5625  25.5000  23.8750  25.1250    16.012533  11157800
# 2001-01-04  28.0000  28.0000  25.4375  26.9375    17.167669  14896200
# 2001-01-05  27.0000  27.0000  25.8750  26.2500    16.729515   6710900
# 2001-01-08  25.4375  26.0000  24.9375  25.6250    16.331194   5900300
#
#                               Name
# Date
# 2001-01-02  Ford Motor Company (F)
# 2001-01-03  Ford Motor Company (F)
# 2001-01-04  Ford Motor Company (F)
# 2001-01-05  Ford Motor Company (F)
# 2001-01-08  Ford Motor Company (F)

# %%
import pandas_datareader.data as web
import datetime

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)

fD = web.DataReader('F', 'yahoo-dividends', start, end)
fD.head()
# Out:
#             Dividends
# Date
# 2001-01-26       0.30
# 2001-04-30       0.30
# 2001-08-01       0.30
# 2001-10-31       0.15
# 2002-01-28       0.10

# %%
#decide date range
style.use('ggplot')

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)
#turn into pandas dataframe
amzn = web.DataReader('AMZN', "yahoo", start, end)
print ("Amazon Inc. (AMZN)")
amzn['Name'] = "Amazon Inc. (AMZN)"
amzn.head()
# Out:
# Amazon Inc. (AMZN)
#                Open     High      Low    Close  Adj Close    Volume  \
# Date
# 2001-01-02  15.8125  16.0000  13.6250  13.8750    13.8750   9203500
# 2001-01-03  13.6250  17.8750  13.5625  17.5625    17.5625  14680400
# 2001-01-04  17.0000  17.5625  15.4375  15.5000    15.5000  10620500
# 2001-01-05  15.5000  15.8750  13.5625  14.5625    14.5625   8798800
# 2001-01-08  14.4375  15.5625  13.7500  14.9375    14.9375  10444700
#
#                           Name
# Date
# 2001-01-02  Amazon Inc. (AMZN)
# 2001-01-03  Amazon Inc. (AMZN)
# 2001-01-04  Amazon Inc. (AMZN)
# 2001-01-05  Amazon Inc. (AMZN)
# 2001-01-08  Amazon Inc. (AMZN)

# %%
amzn = amzn.rename(columns = {'Open': 'AMZN_Open' , 'High' : 'AMZN_High', 'Low': 'AMZN_Low', 'Close': 'AMZN_Close', 'Adj Close': 'AMZN_Adj Close', 'Volume': 'AMZN_Volume'})
amzn.head()
# Out:
#             AMZN_Open  AMZN_High  AMZN_Low  AMZN_Close  AMZN_Adj Close  \
# Date
# 2001-01-02    15.8125    16.0000   13.6250     13.8750         13.8750
# 2001-01-03    13.6250    17.8750   13.5625     17.5625         17.5625
# 2001-01-04    17.0000    17.5625   15.4375     15.5000         15.5000
# 2001-01-05    15.5000    15.8750   13.5625     14.5625         14.5625
# 2001-01-08    14.4375    15.5625   13.7500     14.9375         14.9375
#
#             AMZN_Volume                Name
# Date
# 2001-01-02      9203500  Amazon Inc. (AMZN)
# 2001-01-03     14680400  Amazon Inc. (AMZN)
# 2001-01-04     10620500  Amazon Inc. (AMZN)
# 2001-01-05      8798800  Amazon Inc. (AMZN)
# 2001-01-08     10444700  Amazon Inc. (AMZN)

# %%
#decide date range
style.use('ggplot')

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)
#turn into pandas dataframe
jack = web.DataReader('JACK', "yahoo", start, end)
print ("Jack in the Box Inc. (JACK)")
jack['Name'] = "Jack in the Box Inc. (JACK)"
jack.head()
# Out:
# Jack in the Box Inc. (JACK)
#                 Open      High       Low     Close  Adj Close  Volume  \
# Date
# 2001-01-02  14.62500  14.62500  13.71875  13.96875  13.235295  409600
# 2001-01-03  14.03125  14.43750  13.93750  14.43750  13.679432  415600
# 2001-01-04  14.43750  14.65625  14.43750  14.53125  13.768261  321600
# 2001-01-05  14.59375  14.59375  13.93750  14.15625  13.412951  361600
# 2001-01-08  14.18750  14.75000  14.12500  14.68750  13.916306  414200
#
#                                    Name
# Date
# 2001-01-02  Jack in the Box Inc. (JACK)
# 2001-01-03  Jack in the Box Inc. (JACK)
# 2001-01-04  Jack in the Box Inc. (JACK)
# 2001-01-05  Jack in the Box Inc. (JACK)
# 2001-01-08  Jack in the Box Inc. (JACK)

# %%
jack = jack.rename(columns = {'Open': 'JACK_Open' , 'High' : 'JACK_High', 'Low': 'JACK_Low', 'Close': 'JACK_Close', 'Adj Close': 'JACK_Adj Close', 'Volume': 'JACK_Volume'})
jack.head()
# Out:
#             JACK_Open  JACK_High  JACK_Low  JACK_Close  JACK_Adj Close  \
# Date
# 2001-01-02   14.62500   14.62500  13.71875    13.96875       13.235295
# 2001-01-03   14.03125   14.43750  13.93750    14.43750       13.679432
# 2001-01-04   14.43750   14.65625  14.43750    14.53125       13.768261
# 2001-01-05   14.59375   14.59375  13.93750    14.15625       13.412951
# 2001-01-08   14.18750   14.75000  14.12500    14.68750       13.916306
#
#             JACK_Volume                         Name
# Date
# 2001-01-02       409600  Jack in the Box Inc. (JACK)
# 2001-01-03       415600  Jack in the Box Inc. (JACK)
# 2001-01-04       321600  Jack in the Box Inc. (JACK)
# 2001-01-05       361600  Jack in the Box Inc. (JACK)
# 2001-01-08       414200  Jack in the Box Inc. (JACK)

# %%
import pandas_datareader.data as web
import datetime

start = dt.datetime(2001, 1, 1)
end = dt.datetime(2017, 12, 31)

jackD = web.DataReader('JACK', 'yahoo-dividends', start, end)
jackD.head()
# Out:
#             Dividends
# Date
# 2014-05-22        0.2
# 2014-08-14        0.2
# 2014-11-26        0.2
# 2015-03-04        0.2
# 2015-05-28        0.3

# %%
# Compile Gathered Information for Analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#import decisiontreeclassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
#import logisticregression classifier
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
#import knn classifier
from sklearn.neighbors import KNeighborsClassifier

#for validating your classification model
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn import metrics
from sklearn.metrics import roc_curve, auc

# feature selection
from sklearn.feature_selection import RFE
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import sklearn.linear_model as lm
# Out:
# /anaconda/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#list of tickers
tickers = ['TSLA', 'DPS', 'GOOGL', 'F', 'AMZN', 'JACK']
#pickle indexes our list for us
with open("tickers.pickle", "wb") as t:
    pickle.dump(tickers,t)

# %%
#combines all dataframes into one
con = pd.concat([tsla, dps, googl, f, amzn, jack], axis=1, join='inner')
con.head()
# Out:
#             TSLA_Open  TSLA_High   TSLA_Low  TSLA_Close  TSLA_Adj Close  \
# Date
# 2010-06-29  19.000000      25.00  17.540001   23.889999       23.889999
# 2010-06-30  25.790001      30.42  23.299999   23.830000       23.830000
# 2010-07-01  25.000000      25.92  20.270000   21.959999       21.959999
# 2010-07-02  23.000000      23.10  18.709999   19.200001       19.200001
# 2010-07-06  20.000000      20.00  15.830000   16.110001       16.110001
#
#             TSLA_Volume               Name   DPS_Open   DPS_High    DPS_Low  \
# Date
# 2010-06-29     18766300  Tesla Inc. (TSLA)  37.599998  38.060001  37.349998
# 2010-06-30     17187100  Tesla Inc. (TSLA)  37.680000  38.080002  37.270000
# 2010-07-01      8218800  Tesla Inc. (TSLA)  37.490002  37.549999  36.900002
# 2010-07-02      5139800  Tesla Inc. (TSLA)  37.599998  38.029999  37.250000
# 2010-07-06      6866900  Tesla Inc. (TSLA)  37.709999  38.090000  37.500000
#
# ...

# %%
#pulls only the closing data
conclose = con[['TSLA_Close', 'DPS_Close', 'GOOGL_Close', 'F_Close', 'AMZN_Close', 'JACK_Close']]
conclose = pd.DataFrame(conclose)
conclose.to_csv('joined_closes.csv')
conclose.head()
# Out:
#             TSLA_Close  DPS_Close  GOOGL_Close  F_Close  AMZN_Close  \
# Date
# 2010-06-29   23.889999  37.790001   227.357361     9.88  108.610001
# 2010-06-30   23.830000  37.389999   222.697693    10.08  109.260002
# 2010-07-01   21.959999  37.439999   219.964966    10.57  110.959999
# 2010-07-02   19.200001  37.279999   218.493500    10.28  109.139999
# 2010-07-06   16.110001  37.970001   218.253250    10.16  110.059998
#
#             JACK_Close
# Date
# 2010-06-29   19.730000
# 2010-06-30   19.450001
# 2010-07-01   19.430000
# 2010-07-02   19.190001
# 2010-07-06   18.490000

# %%
conclose_corr = conclose.corr()
conclose_corr.head()
# Out:
#              TSLA_Close  DPS_Close  GOOGL_Close   F_Close  AMZN_Close  \
# TSLA_Close     1.000000   0.860283     0.915882  0.160597    0.820396
# DPS_Close      0.860283   1.000000     0.924187 -0.087494    0.888823
# GOOGL_Close    0.915882   0.924187     1.000000 -0.053600    0.961525
# F_Close        0.160597  -0.087494    -0.053600  1.000000   -0.222849
# AMZN_Close     0.820396   0.888823     0.961525 -0.222849    1.000000
#
#              JACK_Close
# TSLA_Close     0.909089
# DPS_Close      0.945065
# GOOGL_Close    0.920292
# F_Close        0.026518
# AMZN_Close     0.867633

# %%
plt.figure(figsize=(40,40))
sns.heatmap(conclose.corr(), annot=True)

# %%
# !pip install request
# Out:
# ...
#   Running setup.py bdist_wheel for request ... done
#   Stored in directory: /Users/linlyn/Library/Caches/pip/wheels/54/5d/18/01fcd0faf6a9fc088d77f8e227c061d8effd0658d80c9c1fd0
# Successfully built request
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mticker
from matplotlib.finance import candlestick_ohlc
import urllib.request
import numpy as np
import urllib
import datetime as dt

def bytespdate2num(fmt, encoding='utf-8'):
    strconverter = mdates.strpdate2num(fmt)
    def bytesconverter(b):
        s = b.decode(encoding)
        return strconverter(s)
    return bytesconverter
    
def graph_data(stock):

    fig = plt.figure()
    ax1 = plt.subplot2grid((1,1), (0,0))
    
    # Unfortunately, Yahoo's API is no longer available
    # feel free to adapt the code to another source, or use this drop-in replacement.
    
    
    #sets url
    stock_price_url = 'https://pythonprogramming.net/yahoo_finance_replacement'
    source_code = urllib.request.urlopen(stock_price_url).read().decode()
    stock_data = []
    
    #splits the data we retrieved by line
    split_source = source_code.split('\n')
    for line in split_source[1:]:
        split_line = line.split(',')
        if len(split_line) == 7:
            if 'values' not in line and 'labels' not in line:
                stock_data.append(line)
    
    date, closep, highp, lowp, openp, adj_closep, volume = np.loadtxt(stock_data,
                                                          delimiter=',',
                                                          unpack=True,
                                                          converters={0: bytespdate2num('%Y-%m-%d')})

    x = 0
    y = len(date)
    ohlc = []

    #while the length of date is positive, append this
    while x < y:
        append_me = date[x], openp[x], highp[x], lowp[x], closep[x], volume[x]
        ohlc.append(append_me)
        x+=1

    candlestick_ohlc(ax1, ohlc, width=0.8, colorup='#77d879', colordown='#db3f3f')

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)

    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    ax1.xaxis.set_major_locator(mticker.MaxNLocator(10))
    ax1.grid(True)
    
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title(stock)
    plt.legend()
    plt.subplots_adjust(left=0.09, bottom=0.20, right=0.94, top=0.90, wspace=0.2, hspace=0)
    plt.show()


graph_data('TSLA')

# %%
#Model training and testing
def process_data_for_labels(ticker):
    hm_days = 30
    df = pd.read_csv('joined_closes.csv', index_col=0)
    tickers = df.columns.values.tolist()
    
    #fills null values with 0
    df.fillna(0, inplace=True)
    
    #for loop to discover percent change (new - old) / old
    for i in range(1,hm_days+1):
        df['{}_{}d'.format(ticker,i)] = (df[ticker].shift(-i) - df[ticker]) / df[ticker]
        
    df.fillna(0, inplace=True)
    return tickers, df

# %%
def buy_sell_hold(*args):
    cols = [c for c in args]
    
    #if the stock increases by 2%, we should have bought
    requirement = 0.02
    for col in cols:
        if col > requirement:
            return 1
        if col < -requirement:
            return -1
    return 0

# %%
def extract_featuresets(ticker):
    tickers, df = process_data_for_labels(ticker)

    df['{}_target'.format(ticker)] = list(map( buy_sell_hold,
                                               df['{}_1d'.format(ticker)],
                                               df['{}_2d'.format(ticker)],
                                               df['{}_3d'.format(ticker)],
                                               df['{}_4d'.format(ticker)],
                                               df['{}_5d'.format(ticker)],
                                               df['{}_6d'.format(ticker)],
                                               df['{}_7d'.format(ticker)] ))

#This will take any ticker, create the needed dataset, and create our "target" column, which is our label
    vals = df['{}_target'.format(ticker)].values.tolist()
    str_vals = [str(i) for i in vals]
    print('Data spread:',Counter(str_vals))
    print ()

    #accounting for nulls
    df.fillna(0, inplace=True)
    df = df.replace([np.inf, -np.inf], np.nan)
    df.dropna(inplace=True)

    df_vals = df[[ticker for ticker in tickers]].pct_change()
    df_vals = df_vals.replace([np.inf, -np.inf], 0)
    df_vals.fillna(0, inplace=True)

    X = df_vals.values
    y = df['{}_target'.format(ticker)].values
    
    return X,y,df

# %%
def do_ml(ticker):
    X, y, df = extract_featuresets(ticker)

    X_train, X_test, y_train, y_test = cross_validation.train_test_split(X,
                                                        y,
                                                        test_size=0.25)

#this section uses three classifiers, and they vote, to make our model more accurate
    clf = VotingClassifier([('lsvc',svm.LinearSVC()),
                            ('knn',neighbors.KNeighborsClassifier()),
                            ('rfor',RandomForestClassifier())])


    clf.fit(X_train, y_train)
    confidence = clf.score(X_test, y_test)
    print('accuracy:',confidence)
    print()
    print()
    predictions = clf.predict(X_test)
    
    print('predicted class counts:',Counter(predictions))
    
    print()
    print()
    return confidence

# %%
# !pip install statistics
# Out:
# ...
#   Running setup.py bdist_wheel for statistics ... done
#   Stored in directory: /Users/linlyn/Library/Caches/pip/wheels/57/4b/23/14a5c991d6718a8ca1c708a414b7686b0cd33418f210512db3
# Successfully built statistics
# ...

# %%
from collections import Counter
from statistics import mean
from sklearn import svm, cross_validation, neighbors
from sklearn.ensemble import VotingClassifier, RandomForestClassifier

with open("tickers.pickle","rb") as f:
    tickers = pickle.load(f)

accuracies = []
for count,ticker in enumerate(tickers):

    if count%10==0:
        print(count)
        
    accuracy = do_ml(ticker+'_Close') 
    accuracies.append(accuracy)
    print("{}                accuracy: {}.                    Average accuracy:{}".format(ticker,accuracy,mean(accuracies)))
